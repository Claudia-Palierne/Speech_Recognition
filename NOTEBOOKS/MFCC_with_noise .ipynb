# %% [markdown]
# **1. Import**

# %%
# !pip install pydub
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)

# %%
import os
import tensorflow as tf
import soundfile as sf
import numpy as np
import librosa
from glob import glob
from IPython.display import Audio
from pydub import AudioSegment
import random
from math import sqrt

# %%
# path = '/content/drive/MyDrive/Kaggle/speech_recognition/'
path = '/content/gdrive/MyDrive/speech_recognition/'
classes = ['yes', 'no', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'up', 'down']

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
word_index = 3
audio_files = glob(path + classes[word_index] + "/" + random.choice(os.listdir(path + classes[word_index])))

wav, sr = librosa.load(audio_files[0], sr=16000)
wav = librosa.util.fix_length(wav, size=16000)

Audio(wav, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
noises = []
for filename in os.listdir(os.path.join(path, "_noise")):
  file_path = os.path.join(path, "_noise", filename)
  noise = AudioSegment.from_file(file_path)

  max_volume_noise = noise.max
  volume_down = sqrt(max_volume_noise / 40)

  reduced_noise = noise - volume_down

  temp_file = "reduced_volume.wav"
  reduced_noise.export(temp_file, format="wav")

  noise, sr = librosa.load(temp_file, sr=16000)
  start_index = random.randint(0, len(noise) - 16000)
  noise = noise[start_index : start_index + 16000]
  noises.append(noise)
print(len(noises))
# Out:
# 6

# %%
random_index = random.randint(0, len(noises))-1
wav = wav + noises[random_index]
Audio(wav, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **2. Creating the dataset**

# %%
tf_dic_train = {}
tf_dic_val = {}
tf_dic_test = {}
FILES_TO_LOAD = 500

# Read file names from testing_list.txt and validation_list.txt
with open(os.path.join(path, "testing_list.txt"), 'r') as file:
    test_names = file.read().splitlines()
with open(os.path.join(path, "validation_list.txt"), 'r') as file:
    val_names = file.read().splitlines()

for i, label in enumerate(classes):
    train_tmp = []
    val_tmp = []
    test_tmp = []
    for filename in os.listdir(os.path.join(path, label)):
        file_path = os.path.join(path, label, filename)
        random_index = random.randint(0, len(noises))-1
        if "/".join([label, filename]) in test_names:
            if len(test_tmp) >= FILES_TO_LOAD * 0.1:
                pass
            else:
                audio, sample_rate = librosa.load(file_path, sr=16000)
                audio = librosa.util.fix_length(audio, size=16000)
                audio_blend = audio + noises[random_index]
                test_tmp.append(librosa.feature.mfcc(y=audio_blend, sr=sample_rate))
        elif "/".join([label, filename]) in val_names:
            if len(val_tmp) >= FILES_TO_LOAD * 0.1:
                pass
            else:
                audio, sample_rate = librosa.load(file_path, sr=16000)
                audio = librosa.util.fix_length(audio, size=16000)
                audio_blend = audio + noises[random_index]
                val_tmp.append(librosa.feature.mfcc(y=audio_blend, sr=sample_rate))
        else:
            if len(train_tmp) >= FILES_TO_LOAD * 0.8:
                pass
            else:
                audio, sample_rate = librosa.load(file_path, sr=16000)
                audio = librosa.util.fix_length(audio, size=16000)
                audio_blend = audio + noises[random_index]
                train_tmp.append(librosa.feature.mfcc(y=audio_blend, sr=sample_rate))

    train_tmp_tf = tf.data.Dataset.from_tensor_slices(train_tmp)
    val_tmp_tf = tf.data.Dataset.from_tensor_slices(val_tmp)
    test_tmp_tf = tf.data.Dataset.from_tensor_slices(test_tmp)

    tf_dic_train[label] = tf.data.Dataset.zip((train_tmp_tf, tf.data.Dataset.from_tensor_slices(tf.fill((len(train_tmp_tf),), i))))
    tf_dic_val[label] = tf.data.Dataset.zip((val_tmp_tf, tf.data.Dataset.from_tensor_slices(tf.fill((len(val_tmp_tf),), i))))
    tf_dic_test[label] = tf.data.Dataset.zip((test_tmp_tf, tf.data.Dataset.from_tensor_slices(tf.fill((len(test_tmp_tf),), i))))

datasets_train = list(tf_dic_train.values())
datasets_val = list(tf_dic_val.values())
datasets_test = list(tf_dic_test.values())

# %%
from functools import reduce

def dataset_reduce(datasets):
  merged_dataset_reduce = reduce(lambda d1, d2: d1.concatenate(d2), datasets)
  return merged_dataset_reduce.shuffle(buffer_size=1000)

# %%
datasets_train = dataset_reduce(datasets_train)
datasets_val = dataset_reduce(datasets_val)
datasets_test = dataset_reduce(datasets_test)

# %%
len(datasets_train), len(datasets_val), len(datasets_test)
# Out:
# (5171, 650, 650)

# %%
def preprocess_multy(mfcc, label):
  return mfcc, tf.one_hot(label, 13)

# %% [markdown]
# **3. Preprocessing**

# %%
# Train data:
train_data = datasets_train.map(preprocess_multy)
train_data = train_data.cache()
train_data = train_data.shuffle(buffer_size=1000)
train_data = train_data.batch(32)
train_data = train_data.prefetch(16)

# %%
# Validation data:
val_data = datasets_val.map(preprocess_multy)
val_data = val_data.cache()
val_data = val_data.shuffle(buffer_size=1000)
val_data = val_data.batch(32)
val_data = val_data.prefetch(16)

# %%
# Test data:
test_data = datasets_test.map(preprocess_multy)
test_data = test_data.cache()
test_data = test_data.shuffle(buffer_size=1000)
test_data = test_data.batch(32)
test_data = test_data.prefetch(16)

# %%
samples, labels = train_data.as_numpy_iterator().next()
samples.shape, labels.shape
# Out:
# ((32, 20, 32), (32, 13))

# %% [markdown]
# **4. The model**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %%
model = tf.keras.Sequential([
    layers.Reshape((20, 32, 1), input_shape=(20, 32)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    # layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    # layers.Dropout(0.5),
    layers.Dense(64, activation='relu'),
    #layers.Dropout(0.5),
    layers.Dense(13, activation='softmax')
])

# %%
# Define the learning rate schedule

initial_learning_rate = 0.001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=200, decay_rate=0.99, staircase=True)

# Define the optimizer with the learning rate schedule
optimizer_decay = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

# %%
# Compile the model
model.compile(optimizer=optimizer_decay,
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy', tf.keras.metrics.Recall(),tf.keras.metrics.Precision()])

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_1 (Reshape)         (None, 20, 32, 1)         0
#
#  conv2d_3 (Conv2D)           (None, 18, 30, 32)        320
#
#  dropout_3 (Dropout)         (None, 18, 30, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 16, 28, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 14, 64)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 8, 14, 64)         0
#
#  conv2d_5 (Conv2D)           (None, 6, 12, 128)        73856
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 6, 128)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 3, 6, 128)         0
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_3 (Dense)             (None, 128)               295040
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 13)                845
#
# =================================================================
# Total params: 396,813
# Trainable params: 396,813
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **5. Training the model**

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint('model.h5', monitor='val_accuracy', save_best_only=True)

# Train the model with callbacks
history = model.fit(train_data,
                    epochs=50,
                    validation_data=val_data,
                    callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/50
# 162/162 [==============================] - 5s 10ms/step - loss: 2.8175 - accuracy: 0.1452 - recall_1: 0.0159 - precision_1: 0.1559 - val_loss: 2.5912 - val_accuracy: 0.1154 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00
# Epoch 2/50
# 162/162 [==============================] - 1s 7ms/step - loss: 2.3945 - accuracy: 0.1814 - recall_1: 0.0043 - precision_1: 0.4151 - val_loss: 2.4769 - val_accuracy: 0.1554 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00
# Epoch 3/50
# 162/162 [==============================] - 1s 7ms/step - loss: 2.1875 - accuracy: 0.2541 - recall_1: 0.0379 - precision_1: 0.5326 - val_loss: 2.2552 - val_accuracy: 0.2431 - val_recall_1: 0.0062 - val_precision_1: 0.6667
# Epoch 4/50
# 162/162 [==============================] - 1s 7ms/step - loss: 1.9186 - accuracy: 0.3531 - recall_1: 0.1060 - precision_1: 0.5524 - val_loss: 2.1607 - val_accuracy: 0.2677 - val_recall_1: 0.0246 - val_precision_1: 0.7273
# Epoch 5/50
# 162/162 [==============================] - 1s 7ms/step - loss: 1.8201 - accuracy: 0.3982 - recall_1: 0.1503 - precision_1: 0.5873 - val_loss: 1.9069 - val_accuracy: 0.3708 - val_recall_1: 0.0646 - val_precision_1: 0.6562
# Epoch 6/50
# 162/162 [==============================] - 1s 7ms/step - loss: 1.6853 - accuracy: 0.4347 - recall_1: 0.2067 - precision_1: 0.6314 - val_loss: 1.7998 - val_accuracy: 0.4123 - val_recall_1: 0.0954 - val_precision_1: 0.7750
# Epoch 7/50
# 162/162 [==============================] - 1s 8ms/step - loss: 1.5734 - accuracy: 0.4800 - recall_1: 0.2647 - precision_1: 0.6623 - val_loss: 1.6603 - val_accuracy: 0.4585 - val_recall_1: 0.1585 - val_precision_1: 0.8306
# Epoch 8/50
# 162/162 [==============================] - 2s 10ms/step - loss: 1.4407 - accuracy: 0.5301 - recall_1: 0.3353 - precision_1: 0.7063 - val_loss: 1.4923 - val_accuracy: 0.5108 - val_recall_1: 0.2446 - val_precision_1: 0.6913
# Epoch 9/50
# 162/162 [==============================] - 2s 10ms/step - loss: 1.3219 - accuracy: 0.5722 - recall_1: 0.4055 - precision_1: 0.7221 - val_loss: 1.3217 - val_accuracy: 0.5415 - val_recall_1: 0.3431 - val_precision_1: 0.7057
# Epoch 10/50
# 162/162 [==============================] - 2s 10ms/step - loss: 1.1627 - accuracy: 0.6144 - recall_1: 0.4837 - precision_1: 0.7477 - val_loss: 1.0674 - val_accuracy: 0.6446 - val_recall_1: 0.4462 - val_precision_1: 0.7796
# Epoch 11/50
# 162/162 [==============================] - 1s 7ms/step - loss: 1.0498 - accuracy: 0.6579 - recall_1: 0.5417 - precision_1: 0.7791 - val_loss: 1.1035 - val_accuracy: 0.6369 - val_recall_1: 0.4677 - val_precision_1: 0.7361
# Epoch 12/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.9815 - accuracy: 0.6778 - recall_1: 0.5755 - precision_1: 0.7917 - val_loss: 0.9795 - val_accuracy: 0.6631 - val_recall_1: 0.5031 - val_precision_1: 0.7712
# Epoch 13/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.9062 - accuracy: 0.7136 - recall_1: 0.6126 - precision_1: 0.8138 - val_loss: 0.8354 - val_accuracy: 0.7246 - val_recall_1: 0.6000 - val_precision_1: 0.8125
# Epoch 14/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.8419 - accuracy: 0.7256 - recall_1: 0.6380 - precision_1: 0.8194 - val_loss: 0.8497 - val_accuracy: 0.7062 - val_recall_1: 0.6138 - val_precision_1: 0.7996
# Epoch 15/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.8038 - accuracy: 0.7461 - recall_1: 0.6623 - precision_1: 0.8382 - val_loss: 0.8376 - val_accuracy: 0.7292 - val_recall_1: 0.6554 - val_precision_1: 0.8224
# Epoch 16/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.7593 - accuracy: 0.7559 - recall_1: 0.6799 - precision_1: 0.8397 - val_loss: 0.8099 - val_accuracy: 0.7154 - val_recall_1: 0.6308 - val_precision_1: 0.8023
# Epoch 17/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.7099 - accuracy: 0.7677 - recall_1: 0.7003 - precision_1: 0.8474 - val_loss: 0.7497 - val_accuracy: 0.7554 - val_recall_1: 0.6923 - val_precision_1: 0.8427
# Epoch 18/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.6991 - accuracy: 0.7828 - recall_1: 0.7157 - precision_1: 0.8563 - val_loss: 0.6835 - val_accuracy: 0.7662 - val_recall_1: 0.7015 - val_precision_1: 0.8444
# Epoch 19/50
# 162/162 [==============================] - 1s 9ms/step - loss: 0.6459 - accuracy: 0.7969 - recall_1: 0.7387 - precision_1: 0.8668 - val_loss: 0.7538 - val_accuracy: 0.7600 - val_recall_1: 0.6923 - val_precision_1: 0.8364
# Epoch 20/50
# 162/162 [==============================] - 2s 9ms/step - loss: 0.6285 - accuracy: 0.7948 - recall_1: 0.7356 - precision_1: 0.8645 - val_loss: 0.6677 - val_accuracy: 0.7600 - val_recall_1: 0.7108 - val_precision_1: 0.8446
# Epoch 21/50
# 162/162 [==============================] - 2s 10ms/step - loss: 0.6027 - accuracy: 0.8099 - recall_1: 0.7579 - precision_1: 0.8734 - val_loss: 0.6987 - val_accuracy: 0.7523 - val_recall_1: 0.6923 - val_precision_1: 0.8152
# Epoch 22/50
# 162/162 [==============================] - 1s 8ms/step - loss: 0.5673 - accuracy: 0.8149 - recall_1: 0.7675 - precision_1: 0.8765 - val_loss: 0.6746 - val_accuracy: 0.7769 - val_recall_1: 0.7369 - val_precision_1: 0.8418
# Epoch 23/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.5514 - accuracy: 0.8142 - recall_1: 0.7677 - precision_1: 0.8720 - val_loss: 0.6185 - val_accuracy: 0.7923 - val_recall_1: 0.7492 - val_precision_1: 0.8559
# Epoch 24/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.5250 - accuracy: 0.8298 - recall_1: 0.7805 - precision_1: 0.8863 - val_loss: 0.6073 - val_accuracy: 0.7985 - val_recall_1: 0.7631 - val_precision_1: 0.8552
# Epoch 25/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.5260 - accuracy: 0.8261 - recall_1: 0.7776 - precision_1: 0.8839 - val_loss: 0.6235 - val_accuracy: 0.7846 - val_recall_1: 0.7538 - val_precision_1: 0.8478
# Epoch 26/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.4751 - accuracy: 0.8474 - recall_1: 0.8091 - precision_1: 0.9009 - val_loss: 0.5969 - val_accuracy: 0.7923 - val_recall_1: 0.7708 - val_precision_1: 0.8593
# Epoch 27/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.4786 - accuracy: 0.8505 - recall_1: 0.8103 - precision_1: 0.9011 - val_loss: 0.6048 - val_accuracy: 0.7846 - val_recall_1: 0.7615 - val_precision_1: 0.8347
# Epoch 28/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.4853 - accuracy: 0.8439 - recall_1: 0.8039 - precision_1: 0.8988 - val_loss: 0.5998 - val_accuracy: 0.8046 - val_recall_1: 0.7662 - val_precision_1: 0.8676
# Epoch 29/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.4691 - accuracy: 0.8511 - recall_1: 0.8113 - precision_1: 0.8969 - val_loss: 0.6408 - val_accuracy: 0.7938 - val_recall_1: 0.7692 - val_precision_1: 0.8460
# Epoch 30/50
# 162/162 [==============================] - 1s 8ms/step - loss: 0.4365 - accuracy: 0.8623 - recall_1: 0.8250 - precision_1: 0.9096 - val_loss: 0.5815 - val_accuracy: 0.8000 - val_recall_1: 0.7631 - val_precision_1: 0.8626
# Epoch 31/50
# 162/162 [==============================] - 2s 9ms/step - loss: 0.4223 - accuracy: 0.8658 - recall_1: 0.8347 - precision_1: 0.9048 - val_loss: 0.5844 - val_accuracy: 0.7908 - val_recall_1: 0.7631 - val_precision_1: 0.8393
# Epoch 32/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.4367 - accuracy: 0.8608 - recall_1: 0.8258 - precision_1: 0.9039 - val_loss: 0.6270 - val_accuracy: 0.7908 - val_recall_1: 0.7646 - val_precision_1: 0.8496
# Epoch 33/50
# 162/162 [==============================] - 1s 8ms/step - loss: 0.4156 - accuracy: 0.8656 - recall_1: 0.8289 - precision_1: 0.9073 - val_loss: 0.5681 - val_accuracy: 0.8308 - val_recall_1: 0.7938 - val_precision_1: 0.8746
# Epoch 34/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.4057 - accuracy: 0.8780 - recall_1: 0.8466 - precision_1: 0.9155 - val_loss: 0.5584 - val_accuracy: 0.8046 - val_recall_1: 0.7862 - val_precision_1: 0.8574
# Epoch 35/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.4064 - accuracy: 0.8722 - recall_1: 0.8372 - precision_1: 0.9091 - val_loss: 0.6184 - val_accuracy: 0.7969 - val_recall_1: 0.7723 - val_precision_1: 0.8437
# Epoch 36/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.3977 - accuracy: 0.8743 - recall_1: 0.8439 - precision_1: 0.9132 - val_loss: 0.5775 - val_accuracy: 0.8138 - val_recall_1: 0.7815 - val_precision_1: 0.8625
# Epoch 37/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.3644 - accuracy: 0.8861 - recall_1: 0.8575 - precision_1: 0.9197 - val_loss: 0.5317 - val_accuracy: 0.8385 - val_recall_1: 0.8046 - val_precision_1: 0.8775
# Epoch 38/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.3499 - accuracy: 0.8824 - recall_1: 0.8532 - precision_1: 0.9173 - val_loss: 0.5809 - val_accuracy: 0.8015 - val_recall_1: 0.7800 - val_precision_1: 0.8507
# Epoch 39/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.3740 - accuracy: 0.8787 - recall_1: 0.8488 - precision_1: 0.9136 - val_loss: 0.5310 - val_accuracy: 0.8446 - val_recall_1: 0.8154 - val_precision_1: 0.8893
# Epoch 40/50
# 162/162 [==============================] - 1s 9ms/step - loss: 0.3558 - accuracy: 0.8803 - recall_1: 0.8559 - precision_1: 0.9126 - val_loss: 0.5755 - val_accuracy: 0.8215 - val_recall_1: 0.8077 - val_precision_1: 0.8649
# Epoch 41/50
# 162/162 [==============================] - 2s 13ms/step - loss: 0.3576 - accuracy: 0.8867 - recall_1: 0.8586 - precision_1: 0.9164 - val_loss: 0.5625 - val_accuracy: 0.8138 - val_recall_1: 0.7892 - val_precision_1: 0.8593
# Epoch 42/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.3509 - accuracy: 0.8840 - recall_1: 0.8602 - precision_1: 0.9213 - val_loss: 0.5716 - val_accuracy: 0.8277 - val_recall_1: 0.8108 - val_precision_1: 0.8725
# Epoch 43/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.3320 - accuracy: 0.8909 - recall_1: 0.8679 - precision_1: 0.9221 - val_loss: 0.5799 - val_accuracy: 0.8262 - val_recall_1: 0.8062 - val_precision_1: 0.8719
# Epoch 44/50
# 162/162 [==============================] - 1s 7ms/step - loss: 0.3239 - accuracy: 0.8965 - recall_1: 0.8704 - precision_1: 0.9282 - val_loss: 0.5804 - val_accuracy: 0.8354 - val_recall_1: 0.8108 - val_precision_1: 0.8813

# %%
# Save the model

model.save(path + "model_MFCC_noise_drop_84")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.

# %%
from keras.models import load_model

model_loaded = load_model(path + "model_MFCC_noise_drop_84")

# %% [markdown]
# **6. The results**

# %%
# Evaluate the model on the test data
test_loss, test_accuracy, test_recall, test_precision = model_loaded.evaluate(test_data)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
print('Test Recall:', test_recall)
print('Test Precision:', test_precision)
# Out:
# 21/21 [==============================] - 1s 6ms/step - loss: 0.5350 - accuracy: 0.8277 - recall: 0.7985 - precision: 0.8842
# Test Loss: 0.5350462198257446
# Test Accuracy: 0.8276923298835754
# Test Recall: 0.7984615564346313
# Test Precision: 0.8841567039489746
